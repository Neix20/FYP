# %% [markdown]
# # Title: CORRELATION MODEL IN THE ADOPTION OF E-PAYMENT SERVICES

# %% [markdown]
# ## Load Libraries

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

from sklearn import svm, tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, matthews_corrcoef, precision_recall_curve, roc_curve

from scipy.stats import pearsonr, spearmanr, kendalltau, pointbiserialr, chi2, chi2_contingency

from xgboost import XGBClassifier

# %matplotlib inline

# %% [markdown]
# ## Load Custom Made Libraries

# %%
from Utilities.CFS import *
from Utilities.reliefF import *
from Utilities.accuracy import *
from Utilities.corr_matrix import *
from Utilities.forward_selection import *
from Utilities.backward_elimination import *

from Visualization.model_graph import *
from Visualization.network_graph import *

from skfeature.utility.mutual_information import *

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("Dataset/E-payment Cryptocurrency Coin.csv")

# %% [markdown]
# ## Label Binarizer

# %%
def convert_nominal(arr, term_arr):
    tmp_dict = {val:ind for (ind, val) in enumerate(term_arr)}
    return arr.map(lambda x : tmp_dict[x])

# %% [markdown]
# ## Split Dataset

# %%
mod_fac_df = pd.DataFrame()

column_arr = ["Age", "Gender", "Marital Status", "Education Level", "Work Industry", "Work Position"]

for (ind, col_name) in enumerate(column_arr):
    mod_fac_df[col_name] = df.iloc[:, 6 + ind]
    
# Replace Values in Work Industry
mod_fac_df = mod_fac_df.replace("Baking / Finance", "Banking / Finance")

# Label Binarize all columns
# Age
mod_fac_df["Age"] = convert_nominal(mod_fac_df["Age"], ["< 25 years", "26 - 40 years", "41 - 55 years", "above 55 years"])

# Gender
mod_fac_df["Gender"] = convert_nominal(mod_fac_df["Gender"], ["Male", "Female"])

# Marital Status
mod_fac_df["Marital Status"] = convert_nominal(mod_fac_df["Marital Status"], ["Single", "Married", "Other"])

# Education Level
mod_fac_df["Education Level"] = convert_nominal(mod_fac_df["Education Level"], ['Primary school', 'Secondary/High school', 'College/university', 'Graduate school', 'Other'])

# Work Industry
mod_fac_df["Work Industry"] = convert_nominal(mod_fac_df["Work Industry"], ['Banking / Finance', 'Education', 'Healthcare', 'Manufacturing', 'Retail / Hypermarket', 'Other'])

# Work Position
mod_fac_df["Work Position"] = convert_nominal(mod_fac_df["Work Position"], ['Junior management', 'Middle management', 'Top management', 'Professional', 'Other'])

# %%
utaut_fac_df = pd.DataFrame()

column_arr = df.iloc[:, 28:].columns
column_arr = [col.split(": ")[0] for col in column_arr]

for (ind, col_name) in enumerate(column_arr):
    utaut_fac_df[col_name] = df.iloc[:, 28 + ind]
    utaut_fac_df[col_name] = utaut_fac_df[col_name].map(lambda x : x - 1)
    
# Change Data Type to int
utaut_fac_df = utaut_fac_df.astype(int)

# %% [markdown]
# ## Chi-Square Analysis

# %%
arr_df = [mod_fac_df, utaut_fac_df]

c_df = pd.concat(arr_df, axis = 1)

# Convert Values to Int
c_df = c_df.astype(int)

# %%
arr_list = []

for col in c_df.columns:
    tmp_X = c_df.drop(col, axis = 1)
    tmp_Y = c_df.loc[:, col]
    
    tmp_list = []
    
    prob = 0.95
    
    for col_2 in tmp_X.columns:
        chi_df = pd.crosstab(tmp_X.loc[:, col_2], tmp_Y)
        
        stat, p, dof, expected = chi2_contingency(chi_df)
        
        critical = chi2.ppf(prob, dof)
        
        alpha = 1.0 - prob
        
        if abs(stat) >= critical and p <= alpha:
            tmp_list.append(col_2)
            
    arr_list.append((col, tmp_list))
    
arr_list
# Out:
# [('Age',
#   ['Marital Status',
#    'Education Level',
#    'Work Industry',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE4',
#    'EE1',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX2',
#    'AX3',
#    'T2',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('Gender',
#   ['PE1',
#    'PE2',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT4',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE3',
#    'SE4',
#    'AX4',
#    'T1',
#    'T3',
#    'BI1',
#    'BI2',
#    'BI3']),
#  ('Marital Status',
#   ['Age',
#    'Education Level',
#    'Work Industry',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'AX3',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('Education Level',
#   ['Age',
#    'Marital Status',
#    'Work Industry',
#    'Work Position',
#    'AT1',
#    'AT2',
#    'FC1',
#    'FC4',
#    'SE2',
#    'SE3',
#    'SE4',
#    'T4',
#    'BI1',
#    'BI3']),
#  ('Work Industry',
#   ['Age',
#    'Marital Status',
#    'Education Level',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'EE1',
#    'EE3',
#    'SI2',
#    'FC1',
#    'T4']),
#  ('Work Position',
#   ['Age',
#    'Marital Status',
#    'Education Level',
#    'Work Industry',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC4',
#    'AX1',
#    'AX2',
#    'AX4',
#    'T4']),
#  ('PE1',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Work Industry',
#    'Work Position',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('PE2',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Work Industry',
#    'Work Position',
#    'PE1',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('PE3',
#   ['Marital Status',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('PE4',
#   ['Age',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('EE1',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Work Industry',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('EE2',
#   ['Gender',
#    'Marital Status',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('EE3',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Work Industry',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('EE4',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('AT1',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Education Level',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('AT2',
#   ['Marital Status',
#    'Education Level',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('AT3',
#   ['Age',
#    'Marital Status',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('AT4',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('SI1',
#   ['Age',
#    'Marital Status',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('SI2',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Work Industry',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('SI3',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('SI4',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('FC1',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Education Level',
#    'Work Industry',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('FC2',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('FC3',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('FC4',
#   ['Gender',
#    'Education Level',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('SE1',
#   ['Age',
#    'Gender',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('SE2',
#   ['Age',
#    'Education Level',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('SE3',
#   ['Age',
#    'Gender',
#    'Education Level',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('SE4',
#   ['Age',
#    'Gender',
#    'Education Level',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('AX1',
#   ['Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('AX2',
#   ['Age',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('AX3',
#   ['Age',
#    'Marital Status',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('AX4',
#   ['Gender',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('T1',
#   ['Gender',
#    'Marital Status',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('T2',
#   ['Age',
#    'Marital Status',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('T3',
#   ['Gender',
#    'Marital Status',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('T4',
#   ['Age',
#    'Marital Status',
#    'Education Level',
#    'Work Industry',
#    'Work Position',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'BI1',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('BI1',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Education Level',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI2',
#    'BI3',
#    'BI4']),
#  ('BI2',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI3',
#    'BI4']),
#  ('BI3',
#   ['Age',
#    'Gender',
#    'Marital Status',
#    'Education Level',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI4']),
#  ('BI4',
#   ['Age',
#    'Marital Status',
#    'PE1',
#    'PE2',
#    'PE3',
#    'PE4',
#    'EE1',
#    'EE2',
#    'EE3',
#    'EE4',
#    'AT1',
#    'AT2',
#    'AT3',
#    'AT4',
#    'SI1',
#    'SI2',
#    'SI3',
#    'SI4',
#    'FC1',
#    'FC2',
#    'FC3',
#    'FC4',
#    'SE1',
#    'SE2',
#    'SE3',
#    'SE4',
#    'AX1',
#    'AX2',
#    'AX3',
#    'AX4',
#    'T1',
#    'T2',
#    'T3',
#    'T4',
#    'BI1',
#    'BI2',
#    'BI3'])]

# %%
tmp_X = c_df
tmp_Y = df.iloc[:, 17]

# Replace Values
tmp_Y = tmp_Y.replace("No", 0)
tmp_Y = tmp_Y.replace("Yes", 1)

# Convert Data to Int
tmp_Y = tmp_Y.astype(int)

tmp_list = []
    
prob = 0.95

for col in tmp_X.columns:
    chi_df = pd.crosstab(tmp_X.loc[:, col], tmp_Y)
        
    stat, p, dof, expected = chi2_contingency(chi_df)
        
    critical = chi2.ppf(prob, dof)
        
    if abs(stat) >= critical:
        tmp_list.append(col)
        
print(tmp_Y.name)
print(tmp_list)
# Out:
# 6. E-payment purchasing, Loyalty Points and Crypto Coin [(1) Have you ever purchased anything using the E-payment mode?]
# ['Age', 'Gender', 'Marital Status', 'Work Industry', 'Work Position', 'PE1', 'PE2', 'PE4', 'EE1', 'EE2', 'EE3', 'EE4', 'AT1', 'AT2', 'AT3', 'AT4', 'SI1', 'SI2', 'SI3', 'SI4', 'FC1', 'FC2', 'FC3', 'SE1', 'SE2', 'SE4', 'AX1', 'AX2', 'AX3', 'AX4', 'T2', 'T3', 'BI2', 'BI3', 'BI4']

# %%
tmp_X = c_df
tmp_Y = df.iloc[:, 18]

# Replace Values
tmp_Y = tmp_Y.replace("No", 0)
tmp_Y = tmp_Y.replace("Yes", 1)

# Convert Data to Int
tmp_Y = tmp_Y.astype(int)

arr_list = []
    
prob = 0.95

for col in tmp_X.columns:
    chi_df = pd.crosstab(tmp_X.loc[:, col], tmp_Y)
        
    stat, p_val, dof, expected = chi2_contingency(chi_df)
        
    critical = chi2.ppf(prob, dof)
        
    if abs(stat) >= critical:
        arr_list.append((col, stat))
        
print(tmp_Y.name)
# Sort Variables Ascending by P_val
arr_list = sorted(arr_list, key = lambda x : x[1])

arr_df = pd.DataFrame(arr_list, columns = ["Variables", "Chi-Square Value"])

arr_df.style.hide_index()
# Out:
# 6. E-payment purchasing, Loyalty Points and Crypto Coin [(2) In the next six months, do you plan to purchase anything using the E-payment mode?]
# <style  type="text/css" >
# </style><table id="T_c6170_" ><thead>    <tr>        <th class="col_heading level0 col0" >Variables</th>        <th class="col_heading level0 col1" >Chi-Square Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c6170_row0_col0" class="data row0 col0" >PE4</td>
#                         <td id="T_c6170_row0_col1" class="data row0 col1" >10.270128</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row1_col0" class="data row1 col0" >PE2</td>
#                         <td id="T_c6170_row1_col1" class="data row1 col1" >10.450457</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row2_col0" class="data row2 col0" >SE4</td>
#                         <td id="T_c6170_row2_col1" class="data row2 col1" >10.742271</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row3_col0" class="data row3 col0" >T1</td>
#                         <td id="T_c6170_row3_col1" class="data row3 col1" >11.540111</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row4_col0" class="data row4 col0" >BI3</td>
#                         <td id="T_c6170_row4_col1" class="data row4 col1" >12.029613</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row5_col0" class="data row5 col0" >T2</td>
#                         <td id="T_c6170_row5_col1" class="data row5 col1" >12.034293</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row6_col0" class="data row6 col0" >SE3</td>
#                         <td id="T_c6170_row6_col1" class="data row6 col1" >12.072054</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row7_col0" class="data row7 col0" >BI2</td>
#                         <td id="T_c6170_row7_col1" class="data row7 col1" >13.310899</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row8_col0" class="data row8 col0" >FC4</td>
#                         <td id="T_c6170_row8_col1" class="data row8 col1" >14.176667</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row9_col0" class="data row9 col0" >T4</td>
#                         <td id="T_c6170_row9_col1" class="data row9 col1" >16.012116</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row10_col0" class="data row10 col0" >AT1</td>
#                         <td id="T_c6170_row10_col1" class="data row10 col1" >16.691030</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row11_col0" class="data row11 col0" >BI1</td>
#                         <td id="T_c6170_row11_col1" class="data row11 col1" >21.993498</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row12_col0" class="data row12 col0" >Work Position</td>
#                         <td id="T_c6170_row12_col1" class="data row12 col1" >22.667493</td>
#             </tr>
#             <tr>
#                                 <td id="T_c6170_row13_col0" class="data row13 col0" >Education Level</td>
#                         <td id="T_c6170_row13_col1" class="data row13 col1" >24.792732</td>
#             </tr>
#     </tbody></table>
