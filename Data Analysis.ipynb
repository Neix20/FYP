# %% [markdown]
# # Title: CORRELATION MODEL IN THE ADOPTION OF E-PAYMENT SERVICES

# %% [markdown]
# ## Load Libraries

# %%
import time
import numpy as np
import pandas as pd

from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from scipy.stats import pearsonr, spearmanr, kendalltau, pointbiserialr

# %% [markdown]
# ## Load Custom Made Libraries

# %%
from Utilities.CFS import *
from Utilities.accuracy import *
from Utilities.corr_matrix import *
from Utilities.forward_selection import *
from Utilities.backward_elimination import *

from Visualization.model_graph import *
from Visualization.network_graph import *

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("Dataset/E-payment Cryptocurrency Coin.csv")

# %% [markdown]
# ## Analysis of Dataset

# %% [markdown]
# #### Classify the features into several categories
# As we can see from the above code, there are a total of 64 features in this dataset. For easier data analysis, we will be categorizing the features into several groups so that we can have more accurate analysis

# %%
df.columns
# Out:
# Index(['Timestamp', 'Name', 'Email', 'Mobile Phone (H/p)',
#        'Where were you born? ', 'Where are you residing now? ', 'Q1. Age',
#        'Q2. Gender', 'Q3. What is your marital status?',
#        'Q4. What is your highest level of education?',
#        'Q5. What industry do you work in?',
#        'Q6. What is your position level at work?',
#        '1. Do you own any of the following?',
#        '2. What operating system does your smartphone/Tablet operate?',
#        '3. Have you made any electronic payments in the past 12 months?',
#        '4. Investment Portfolio (Tick what is relevant)',
#        '5. Investment Cryptocurrency Coin (Tick what is relevant)',
#        '6. E-payment purchasing, Loyalty Points and Crypto Coin [(1) Have you ever purchased anything using the E-payment mode?]',
#        '6. E-payment purchasing, Loyalty Points and Crypto Coin [(2) In the next six months, do you plan to purchase anything using the E-payment mode?]',
#        '6. E-payment purchasing, Loyalty Points and Crypto Coin [(3) Do you plan to purchase any gifts/tickets etc this year using the E-payment mode?]',
#        '6. E-payment purchasing, Loyalty Points and Crypto Coin [(4) Do you have the Investment in Crypto?]',
#        '6. E-payment purchasing, Loyalty Points and Crypto Coin [(5) Do you plan to convert your Crypto Investment to Crypto Coins for E-payment?]',
#        '6. E-payment purchasing, Loyalty Points and Crypto Coin [(6) Do you have the loyalty points that can be used for E-payment transactions?]',
#        '6. E-payment purchasing, Loyalty Points and Crypto Coin [(7) Are you interested to turn your loyalty points into Crypto coins for E-payment?]',
#        '6. E-payment purchasing, Loyalty Points and Crypto Coin [(8) Do you like to have the credit/debit card, e-wallet, Crypto Coin on a single platform for E-payment transactions?]',
#        '6. E-payment purchasing, Loyalty Points and Crypto Coin [(9) Do you like to have the platform of a survey redemption solution for Crypto Coin E-payment transactions?]',
#        '6. E-payment purchasing, Loyalty Points and Crypto Coin [(10) Do you like the points collected from shopping that can be used for Crypto Coin E-payment transactions?]',
#        'Type of gifts you like',
#        'PE1: I find Blockchain / Cryptocurrency Coin useful in me.',
#        'PE2: Using Blockchain / Cryptocurrency Coin enables me to accomplish tasks more quickly.',
#        'PE3: Using Blockchain / Cryptocurrency Coin increases my productivity.',
#        'PE4: Using Blockchain / Cryptocurrency Coin increases my chances of getting more choices.',
#        'EE1: My interaction with Blockchain / Cryptocurrency Coin is clear and understandable.',
#        'EE2: It is easy for me to become skillful at using Blockchain / Cryptocurrency Coin.',
#        'EE3: I find Blockchain / Cryptocurrency Coin easy to use.',
#        'EE4: Learning to operate Blockchain / Cryptocurrency Coin is easy for me.',
#        'AT1: Using Blockchain / Cryptocurrency Coin is a good idea.',
#        'AT2: Blockchain / Cryptocurrency Coin makes effort more interesting.',
#        'AT3: Working with Blockchain / Cryptocurrency Coin is fun.',
#        'AT4: I like working with Blockchain / Cryptocurrency Coin.',
#        'SI1: People who influence my behavior think that I should use Blockchain / Cryptocurrency Coin.',
#        'SI2: People who are important to me think that I should use Blockchain / Cryptocurrency Coin.',
#        'SI3: There are more options in the marketplace for the use of Blockchain / Cryptocurrency Coin.',
#        'SI4: In general, the company has supported the use of Blockchain / Cryptocurrency Coin.',
#        'FC1: I have the resources necessary to use Blockchain / Cryptocurrency Coin.',
#        'FC2: I have the knowledge necessary to use Blockchain / Cryptocurrency Coin.',
#        'FC3: Blockchain / Cryptocurrency Coin is compatible with other systems I use.',
#        'FC4: A specific person (or group) is available for assistance with Blockchain / Cryptocurrency Coin difficulties.',
#        'SE1: I can complete a job or task using Blockchain / Cryptocurrency Coin , if there is no one around to tell me what to do.',
#        'SE2: I can complete a job or task using Blockchain / Cryptocurrency Coin , if I can call someone for help if I get stuck.',
#        'SE3: I can complete a job or task using Blockchain / Cryptocurrency Coin , if I have a lot of time to complete the job for which the software is provided.',
#        'SE4: I can complete a job or task using Blockchain / Cryptocurrency Coin , if I have just the built-in help facility for assistance.',
#        'AX1: I feel apprehensive about using Blockchain / Cryptocurrency Coin.',
#        'AX2: It scares me to think that I could lose a lot of information using Blockchain / Cryptocurrency Coin by hitting the wrong key.',
#        'AX3: I hesitate to use Blockchain / Cryptocurrency Coin for fear of making mistakes I cannot correct.',
#        'AX4: Blockchain / Cryptocurrency Coin is somewhat intimidating to me.',
#        'T1: I feel comfortable using Blockchain / Cryptocurrency Coin.',
#        'T2: I feel the reliability to use Blockchain / Cryptocurrency Coin.',
#        'T3: I am glad about the service quality to use Blockchain / Cryptocurrency Coin.',
#        'T4: Blockchain / Cryptocurrency Coin Integrity is vital to me.',
#        'BI1: I intend to use Blockchain / Cryptocurrency Coin.',
#        'BI2: I plan to invest Blockchain / Cryptocurrency Coin.',
#        'BI3: I plan to have Blockchain / Cryptocurrency Coin as an E-Wallet.',
#        'BI4: I plan to use Blockchain / Cryptocurrency Coin for E-payment transaction to buy stuff.'],
#       dtype='object')

# %% [markdown]
# #### Demographic Factors
# This demographic questions asks respondents basic questions such as name, age. Demographic features might have some importance in determining the factors of a user behavioral intention to adopt blockchain as a payment method

# %%
df.iloc[:, :6].head()
# Out:
#                      Timestamp                Name  \
# 0  2021/03/21 5:20:37 PM GMT+8            Chai Yin
# 1  2021/03/21 5:41:28 PM GMT+8            Mabellyn
# 2  2021/03/21 8:12:35 PM GMT+8        Lee Beng Bee
# 3  2021/03/21 9:45:09 PM GMT+8         Salman Faiz
# 4  2021/03/22 2:50:36 PM GMT+8  Darsini Manibalan
#
#                           Email Mobile Phone (H/p) Where were you born?   \
# 0          eeuchaiyin@gmail.com         0122387678              Malaysia
# 1        mabellyn2000@gmail.com         0122445254              Malaysia
# 2           leebbee70@gmail.com         0124587029              Malaysia
# 3      salmanfaiz99@hotmail.com        017-6374699                Others
# 4  darsini96manibalan@gmail.com         0122804107              Malaysia
#
#   Where are you residing now?
# 0                     Malaysia
# 1                     Malaysia
# 2                     Malaysia
# 3                     Malaysia
# 4                     Malaysia

# %% [markdown]
# #### Moderated Variables

# %%
# Replace Values
df.iloc[:, [10]] = df.iloc[:, [10]].replace("Baking / Finance", "Banking / Finance")

# %%
df.iloc[:, 6:12].head()
# Out:
#          Q1. Age Q2. Gender Q3. What is your marital status?  \
# 0     < 25 years     Female                           Single
# 1     < 25 years     Female                           Single
# 2  41 - 55 years     Female                           Single
# 3     < 25 years       Male                           Single
# 4     < 25 years     Female                           Single
#
#   Q4. What is your highest level of education?  \
# 0                           College/university
# 1                           College/university
# 2                           College/university
# 3                           College/university
# 4                           College/university
#
#   Q5. What industry do you work in? Q6. What is your position level at work?
# 0                 Banking / Finance                                    Other
# 1                             Other                                    Other
# 2                     Manufacturing                        Middle management
# 3                         Education                                    Other
# 4                             Other                                    Other

# %% [markdown]
# #### Basic Factors
# These questions provides an insight on the familiarity respondents have towards blockchain and cryptocurrency. These questions are all boolean valued questions.

# %%
tmp_df = df.iloc[:, 12:28]

# Show 6 Columns at 1 Row
for col_ind in range(0, tmp_df.shape[1], 6):
    display(tmp_df.iloc[:, col_ind:col_ind + 6].head())
# Out:
#                  1. Do you own any of the following?  \
# 0  Mobile Smartphone;Bank Cards (Credit, Debit, P...
# 1  Mobile Smartphone;Bank Cards (Credit, Debit, P...
# 2  Mobile Smartphone;Bank Cards (Credit, Debit, P...
# 3  Mobile Smartphone;Bank Cards (Credit, Debit, P...
# 4  Mobile Smartphone;Bank Cards (Credit, Debit, P...
#
#   2. What operating system does your smartphone/Tablet operate?  \
# 0                             Android (Samsung, etc)
# 1                             Android (Samsung, etc)
# 2                             Android (Samsung, etc)
# 3                             Android (Samsung, etc)
# 4                                       iOS (iPhone)
#
#   3. Have you made any electronic payments in the past 12 months?  \
# 0  Yes (Mobile);Yes (Bank Cards (i.e. Credit, Deb...
# 1    Yes (Bank Cards (i.e. Credit, Debit, Pre-paid))
# 2  Yes (Bank Cards (i.e. Credit, Debit, Pre-paid)...
# 3  Yes (Mobile);Yes (Bank Cards (i.e. Credit, Deb...
# 4  Yes (Mobile);Yes (Bank Cards (i.e. Credit, Deb...
#
#   4. Investment Portfolio (Tick what is relevant)  \
# 0                                          Stocks
# 1                                           Other
# 2                                    Crypto;Other
# 3                                  Currency;Other
# 4                                        Currency
#
#   5. Investment Cryptocurrency Coin (Tick what is relevant)  \
# 0                                                 pi
# 1                                                 No
# 2                                           Ethereum
# 3                                                 No
# 4                                                 No
#
#   6. E-payment purchasing, Loyalty Points and Crypto Coin [(1) Have you ever purchased anything using the E-payment mode?]
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#   6. E-payment purchasing, Loyalty Points and Crypto Coin [(2) In the next six months, do you plan to purchase anything using the E-payment mode?]  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   6. E-payment purchasing, Loyalty Points and Crypto Coin [(3) Do you plan to purchase any gifts/tickets etc this year using the E-payment mode?]  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   6. E-payment purchasing, Loyalty Points and Crypto Coin [(4) Do you have the Investment in Crypto?]  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   6. E-payment purchasing, Loyalty Points and Crypto Coin [(5) Do you plan to convert your Crypto Investment to Crypto Coins for E-payment?]  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   6. E-payment purchasing, Loyalty Points and Crypto Coin [(6) Do you have the loyalty points that can be used for E-payment transactions?]  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#   6. E-payment purchasing, Loyalty Points and Crypto Coin [(7) Are you interested to turn your loyalty points into Crypto coins for E-payment?]
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#   6. E-payment purchasing, Loyalty Points and Crypto Coin [(8) Do you like to have the credit/debit card, e-wallet, Crypto Coin on a single platform for E-payment transactions?]  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   6. E-payment purchasing, Loyalty Points and Crypto Coin [(9) Do you like to have the platform of a survey redemption solution for Crypto Coin E-payment transactions?]  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   6. E-payment purchasing, Loyalty Points and Crypto Coin [(10) Do you like the points collected from shopping that can be used for Crypto Coin E-payment transactions?]  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#                               Type of gifts you like
# 0  Shopping Voucher;Cryptocurrency Coin;Loyalty P...
# 1  Airline / Holiday Voucher;Money in my e-wallet...
# 2  Cryptocurrency Coin;Money in my e-wallet (e.g:...
# 3  Shopping Voucher;Loyalty Points;Food Voucher;M...
# 4  Shopping Voucher;Cryptocurrency Coin;Loyalty P...

# %% [markdown]
# #### UTAUT Factors
# As the survey was conducted based on UTAUT model (the entire premise of this project is to see whether or not statisical analysis can be replaced using Machine Learning), therefore, there is a need to categorize questions based on UTAUT factors.

# %% [markdown]
# There are a total of 32 UTAUT factors for this dataset, namely:
# * Performance Expectancy (PE)
# * Effort Expectancy (EE)
# * Attitude toward Using Technology (AT)
# * Social Influence (SI)
# * Facilitating Conditions (FC)
# * Self-Efficacy (SE)
# * Anxiety (AX)
# * Trust (T)

# %% [markdown]
# ##### Performance Expectancy (PE)
# > The degree to which users believe that using e-payment service will improve their efficiency of work or life

# %%
df.iloc[:, 28:32].head()
# Out:
#    PE1: I find Blockchain / Cryptocurrency Coin useful in me.  \
# 0                                                  2
# 1                                                  1
# 2                                                  4
# 3                                                  3
# 4                                                  3
#
#    PE2: Using Blockchain / Cryptocurrency Coin enables me to accomplish tasks more quickly.  \
# 0                                                  2
# 1                                                  1
# 2                                                  5
# 3                                                  3
# 4                                                  3
#
#    PE3: Using Blockchain / Cryptocurrency Coin increases my productivity.  \
# 0                                                  2
# 1                                                  1
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    PE4: Using Blockchain / Cryptocurrency Coin increases my chances of getting more choices.
# 0                                                  2
# 1                                                  1
# 2                                                  5
# 3                                                  3
# 4                                                  4

# %% [markdown]
# ##### Effort Expectancy (EE)
# > The degree to which consumers perceive e-payment service as easy to understand and use.

# %%
df.iloc[:, 32:36].head()
# Out:
#    EE1: My interaction with Blockchain / Cryptocurrency Coin is clear and understandable.  \
# 0                                                  3
# 1                                                  1
# 2                                                  3
# 3                                                  2
# 4                                                  3
#
#    EE2: It is easy for me to become skillful at using Blockchain / Cryptocurrency Coin.  \
# 0                                                  3
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    EE3: I find Blockchain / Cryptocurrency Coin easy to use.  \
# 0                                                  3
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    EE4: Learning to operate Blockchain / Cryptocurrency Coin is easy for me.
# 0                                                  3
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4

# %% [markdown]
# ##### Attitude Towards Using Technology (AT)
# > The degree of an individual overall affective reaction to using e-payment system.

# %%
df.iloc[:,36:40].head()
# Out:
#    AT1: Using Blockchain / Cryptocurrency Coin is a good idea.  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#    AT2: Blockchain / Cryptocurrency Coin makes effort more interesting.  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    AT3: Working with Blockchain / Cryptocurrency Coin is fun.  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    AT4: I like working with Blockchain / Cryptocurrency Coin.
# 0                                                  3
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4

# %% [markdown]
# ##### Social Influence (SI)
# > Users’ perceived support level by those who are important to them or those who are influential in their choice of e-payment service

# %%
df.iloc[:, 40:44].head()
# Out:
#    SI1: People who influence my behavior think that I should use Blockchain / Cryptocurrency Coin.  \
# 0                                                  3
# 1                                                  1
# 2                                                  3
# 3                                                  2
# 4                                                  2
#
#    SI2: People who are important to me think that I should use Blockchain / Cryptocurrency Coin.  \
# 0                                                  3
# 1                                                  1
# 2                                                  3
# 3                                                  2
# 4                                                  3
#
#    SI3: There are more options in the marketplace for the use of Blockchain / Cryptocurrency Coin.  \
# 0                                                  4
# 1                                                  3
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    SI4: In general, the company has supported the use of Blockchain / Cryptocurrency Coin.
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  3

# %% [markdown]
# ##### Facilitating Conditions (FC)
# > The degree of support of technical infrastructures and resources required towards using e-payment service app.

# %%
df.iloc[:, 44:48].head()
# Out:
#    FC1: I have the resources necessary to use Blockchain / Cryptocurrency Coin.  \
# 0                                                  2
# 1                                                  1
# 2                                                  3
# 3                                                  2
# 4                                                  2
#
#    FC2: I have the knowledge necessary to use Blockchain / Cryptocurrency Coin.  \
# 0                                                  2
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#    FC3: Blockchain / Cryptocurrency Coin is compatible with other systems I use.  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#    FC4: A specific person (or group) is available for assistance with Blockchain / Cryptocurrency Coin difficulties.
# 0                                                  2
# 1                                                  1
# 2                                                  3
# 3                                                  2
# 4                                                  3

# %% [markdown]
# ##### Self-Efficacy (SE)
# > What user believe himself or herself is capable of using e-payment system

# %%
df.iloc[:, 48:52].head()
# Out:
#    SE1: I can complete a job or task using Blockchain / Cryptocurrency Coin , if there is no one around to tell me what to do.  \
# 0                                                  2
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    SE2: I can complete a job or task using Blockchain / Cryptocurrency Coin , if I can call someone for help if I get stuck.  \
# 0                                                  4
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    SE3: I can complete a job or task using Blockchain / Cryptocurrency Coin , if I have a lot of time to complete the job for which the software is provided.  \
# 0                                                  4
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    SE4: I can complete a job or task using Blockchain / Cryptocurrency Coin , if I have just the built-in help facility for assistance.
# 0                                                  4
# 1                                                  1
# 2                                                  4
# 3                                                  3
# 4                                                  3

# %% [markdown]
# ##### Anxiety (AX)
# > The unwillingness of user to use e-payment system

# %%
df.iloc[:, 52:56].head()
# Out:
#    AX1: I feel apprehensive about using Blockchain / Cryptocurrency Coin.  \
# 0                                                  3
# 1                                                  5
# 2                                                  3
# 3                                                  3
# 4                                                  5
#
#    AX2: It scares me to think that I could lose a lot of information using Blockchain / Cryptocurrency Coin by hitting the wrong key.  \
# 0                                                  4
# 1                                                  5
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    AX3: I hesitate to use Blockchain / Cryptocurrency Coin for fear of making mistakes I cannot correct.  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    AX4: Blockchain / Cryptocurrency Coin is somewhat intimidating to me.
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  4

# %% [markdown]
# ##### Trust (T)
# > The willingness of an user to obey the other party’s action.

# %%
df.iloc[:, 56:60].head()
# Out:
#    T1: I feel comfortable using Blockchain / Cryptocurrency Coin.  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    T2: I feel the reliability to use Blockchain / Cryptocurrency Coin.  \
# 0                                                  1
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    T3: I am glad about the service quality to use Blockchain / Cryptocurrency Coin.  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    T4: Blockchain / Cryptocurrency Coin Integrity is vital to me.
# 0                                                  3
# 1                                                  2
# 2                                                  4
# 3                                                  3
# 4                                                  4

# %% [markdown]
# ##### Behavioral Intention to Use the System (BI)
# > The degree to user intends to accept and use the e-payment system

# %%
df.iloc[:, 60:].head()
# Out:
#    BI1: I intend to use Blockchain / Cryptocurrency Coin.  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    BI2: I plan to invest Blockchain / Cryptocurrency Coin.  \
# 0                                                  3
# 1                                                  2
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#    BI3: I plan to have Blockchain / Cryptocurrency Coin as an E-Wallet.  \
# 0                                                  3
# 1                                                  2
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    BI4: I plan to use Blockchain / Cryptocurrency Coin for E-payment transaction to buy stuff.
# 0                                                  3
# 1                                                  2
# 2                                                  4
# 3                                                  3
# 4                                                  4

# %% [markdown]
# ## Descriptive Statistics
#
# * Mean is the average of a set of values.
# * Standard Deviation (Std) is the measure of the amount of variation or dispersion of a set of values.
# * Kurtosis is the measure of the combined weight of a distribution's tails relative to the center of the distribution.
# * Skewness is a measure of the asymmetry of the probability distribution of a real-valued random variable about its mean.

# %%
def get_descriptive(df, index_arr, column_arr):
    desc_df = pd.get_dummies(df.stack()).groupby(level=1).sum()
    desc_df["Mean"] = desc_df.apply(np.mean, axis = 1)
    desc_df["Std"] = desc_df.apply(np.std, axis = 1)
    desc_df["Kurtosis"] = desc_df.apply(kurtosis, axis = 1)
    desc_df["Skewness"] = desc_df.apply(skew, axis = 1)
    desc_df.index = index_arr
    desc_df = desc_df.loc[:, column_arr + ["Mean", "Std", "Kurtosis", "Skewness"]]
    return desc_df

# %%
index_arr = ["Age"]
column_arr = ["< 25 years", "26 - 40 years", "41 - 55 years", "above 55 years"]
get_descriptive(df.iloc[:, [6]], index_arr, column_arr)
# Out:
#      < 25 years  26 - 40 years  41 - 55 years  above 55 years  Mean  \
# Age          83             95             86              22  71.5
#
#            Std  Kurtosis  Skewness
# Age  25.865034 -1.492837 -0.352645

# %%
index_arr = ["Gender"]
column_arr = ["Male", "Female"]
get_descriptive(df.iloc[:, [7]], index_arr, column_arr)
# Out:
#         Male  Female   Mean        Std  Kurtosis  Skewness
# Gender   170     116  143.0  22.045408 -0.947345 -0.253056

# %%
index_arr = ["Marital Status"]
column_arr = ["Single", "Married", "Other"]
get_descriptive(df.iloc[:, [8]], index_arr, column_arr)
# Out:
#                 Single  Married  Other       Mean        Std  Kurtosis  \
# Marital Status     143      136      7  95.333333  54.149484 -1.311429
#
#                 Skewness
# Marital Status -0.056109

# %%
index_arr = ["Education Level"]
column_arr = ['Primary school', 'Secondary/High school', 'College/university', 'Graduate school', 'Other']
get_descriptive(df.iloc[:, [9]], index_arr, column_arr)
# Out:
#                  Primary school  Secondary/High school  College/university  \
# Education Level               6                     41                 187
#
#                  Graduate school  Other  Mean        Std  Kurtosis  Skewness
# Education Level               46      6  57.2  61.208387   1.05885  1.568724

# %%
index_arr = ["Work Industry"]
column_arr = ['Banking / Finance', 'Education', 'Healthcare', 'Manufacturing', 'Retail / Hypermarket', 'Other']
get_descriptive(df.iloc[:, [10]], index_arr, column_arr)
# Out:
#                Banking / Finance  Education  Healthcare  Manufacturing  \
# Work Industry                 34         62           6             31
#
#                Retail / Hypermarket  Other       Mean        Std  Kurtosis  \
# Work Industry                    17    136  47.666667  39.909421  1.288376
#
#                Skewness
# Work Industry  1.453002

# %%
index_arr = ["Work Position"]
column_arr = ['Junior management', 'Middle management', 'Top management', 'Professional', 'Other']
get_descriptive(df.iloc[:, [11]], index_arr, column_arr)
# Out:
#                Junior management  Middle management  Top management  \
# Work Position                 32                 70              26
#
#                Professional  Other  Mean        Std  Kurtosis  Skewness
# Work Position            47    111  57.2  28.198109  -0.10556  0.659054
